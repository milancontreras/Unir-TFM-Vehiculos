# %%
# %sql
CREATE DATABASE IF NOT EXISTS tfm_silver_ctg
COMMENT 'Homologaciones Capa Plata';

# %%
# %sql
--DROP TABLE IF EXISTS tfm_silver_ctg.cat_tipo_vehiculo;
CREATE TABLE IF NOT EXISTS tfm_silver_ctg.cat_tipo_vehiculo (
    tipo_vehiculo_id              BIGINT GENERATED ALWAYS AS IDENTITY, 
    tipo_vehiculo                 STRING,    
    descripcion                   STRING,    
    fecha_desde                   TIMESTAMP,
    fecha_hasta                   TIMESTAMP
)
USING DELTA
COMMENT 'Catálogo de tipo vehiculos';
