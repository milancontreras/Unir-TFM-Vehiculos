# %%
# %sql
CREATE DATABASE IF NOT EXISTS tfm_silver_ctg
COMMENT 'Homologaciones Capa Plata';

# %%
# %sql
--DROP TABLE IF EXISTS tfm_silver_ctg.cat_marca;
CREATE TABLE IF NOT EXISTS tfm_silver_ctg.cat_marca (
    marca_id                    BIGINT GENERATED ALWAYS AS IDENTITY, 
    marca                      STRING,    
    descripcion                STRING,    
    fecha_desde                TIMESTAMP,
    fecha_hasta                TIMESTAMP
)
USING DELTA
COMMENT 'Catálogo de marcas';
