# %%
# %sql
CREATE DATABASE IF NOT EXISTS tfm_silver_ctg
COMMENT 'Homologaciones Capa Plata';

# %%
# %sql
--DROP TABLE IF EXISTS tfm_silver_ctg.cat_subclase;
CREATE TABLE IF NOT EXISTS tfm_silver_ctg.cat_subclase (
    subclase_id                   BIGINT GENERATED ALWAYS AS IDENTITY, 
    subclase                      STRING,    
    descripcion                   STRING,    
    fecha_desde                   TIMESTAMP,
    fecha_hasta                   TIMESTAMP
)
USING DELTA
COMMENT 'Catálogo de subclases vehiculos';
