# %%
spark.sql("DROP TABLE IF EXISTS tmp_hmg_tipo_combustible")

spark.sql("""
    CREATE OR REPLACE TABLE tmp_hmg_tipo_combustible AS
    SELECT * FROM tfm_silver_hmg.homologacion WHERE dominio = 'tipo_combustible' LIMIT 0
""")

# %%
spark.sql("""
    INSERT INTO tmp_hmg_tipo_combustible (dominio, columna_origen, valor_original, catalog_id, fecha_desde, fecha_hasta) VALUES
    ('tipo_combustible', 'TIPO_COMBUSTIBLE', 'ALCOHOL', 13, '1900-01-01 00:00:00' , NULL ),
    ('tipo_combustible', 'TIPO_COMBUSTIBLE', 'DIESEL', 2, '1900-01-01 00:00:00' , NULL ),
    ('tipo_combustible', 'TIPO_COMBUSTIBLE', 'DUAL_GAS_GASOLINA', 3, '1900-01-01 00:00:00' , NULL ),
    ('tipo_combustible', 'TIPO_COMBUSTIBLE', 'ELECTRICO', 4, '1900-01-01 00:00:00' , NULL ),
    ('tipo_combustible', 'TIPO_COMBUSTIBLE', 'GASOLINA', 5, '1900-01-01 00:00:00' , NULL ),
    ('tipo_combustible', 'TIPO_COMBUSTIBLE', 'GAS_LICUADO_PETROLEO', 6, '1900-01-01 00:00:00' , NULL ),
    ('tipo_combustible', 'TIPO_COMBUSTIBLE', 'GAS_NATURAL_COMPRIMIDO', 7, '1900-01-01 00:00:00' , NULL ),
    ('tipo_combustible', 'TIPO_COMBUSTIBLE', 'HIBRIDO_DIESEL_BATERIAS', 8, '1900-01-01 00:00:00' , NULL ),
    ('tipo_combustible', 'TIPO_COMBUSTIBLE', 'HIBRIDO_GASOLINA_BATERIAS', 9, '1900-01-01 00:00:00' , NULL ),
    ('tipo_combustible', 'TIPO_COMBUSTIBLE', 'NO_UTILIZA', 10, '1900-01-01 00:00:00' , NULL ),
    ('tipo_combustible', 'TIPO_COMBUSTIBLE', 'OTROS', 11, '1900-01-01 00:00:00' , NULL ),
    ('tipo_combustible', 'TIPO_COMBUSTIBLE', 'SOLAR', 12, '1900-01-01 00:00:00' , NULL );
""")

# %%
# %sql
INSERT INTO tfm_silver_hmg.homologacion (dominio, columna_origen, valor_original, catalog_id, fecha_desde, fecha_hasta)
SELECT t.dominio, t.columna_origen,t.valor_original, t.catalog_id ,t.fecha_desde, t.fecha_hasta
FROM tmp_hmg_tipo_combustible t
LEFT JOIN tfm_silver_hmg.homologacion c
  ON t.dominio = c.dominio
  AND t.columna_origen = c.columna_origen
  AND t.valor_original = c.valor_original
  AND t.catalog_id = c.catalog_id
WHERE c.regla_id IS NULL

# %%
spark.sql("DROP TABLE IF EXISTS tmp_hmg_tipo_combustible")
