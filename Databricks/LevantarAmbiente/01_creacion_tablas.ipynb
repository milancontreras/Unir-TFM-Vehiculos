# %%
# %run "../Tablas/tfm_config.mapeo_cabeceras"

# %%
# %run "../Tablas/tfm_config.normalizacion_columnas"

# %%
# %run "../Tablas/tfm_bronze.tabla_estado"

# %%
# %run "../Tablas/tfm_silver.tabla_datos_vehiculos"

# %%
# %run "../Tablas/tfm_silver.tabla_estado"

# %%
# %run "../Tablas/tfm_silver_ctg.catalogo_clase"

# %%
# %run "../Tablas/tfm_silver_ctg.catalogo_marca"

# %%
# %run "../Tablas/tfm_silver_ctg.catalogo_pais"

# %%
# %run "../Tablas/tfm_silver_ctg.catalogo_subclase"

# %%
# %run "../Tablas/tfm_silver_ctg.catalogo_tipo_combustible"

# %%
# %run "../Tablas/tfm_silver_ctg.catalogo_tipo_comprador"

# %%
# %run "../Tablas/tfm_silver_ctg.catalogo_tipo_servicio"

# %%
# %run "../Tablas/tfm_silver_ctg.catalogo_tipo_transaccion"

# %%
# %run "../Tablas/tfm_silver_ctg.catalogo_tipo_vehiculo"

# %%
# %run "../Tablas/tfm_silver_hmg.homologacion"
