# %% [markdown]
# # Casteo de columnas

# %% [markdown]
# ## 2017

# %%
# %sql
DELETE FROM tfm_config.column_cast_rules WHERE source_year = 2017;
INSERT INTO tfm_config.column_cast_rules VALUES
('vehiculos', 'FECHA_PROCESO','date', 'm'  ,NULL, TRUE, '2017-01-01',NULL, 2017,'Regla FECHA_PROCESO 2017'),
('vehiculos', 'FECHA_COMPRA' ,'date', 'm'  ,NULL, TRUE, '2017-01-01',NULL, 2017,'Regla FECHA_PROCESO 2017');

# %% [markdown]
# ## 2018

# %%
# %sql
DELETE FROM tfm_config.column_cast_rules WHERE source_year = 2018;
INSERT INTO tfm_config.column_cast_rules VALUES
('vehiculos', 'FECHA_PROCESO','date', 'd/M/yyyy'  ,NULL, TRUE, '2017-01-01',NULL, 2018,'Regla FECHA_PROCESO 2018'),
('vehiculos', 'FECHA_COMPRA' ,'date', 'd/M/yyyy'  ,NULL, TRUE, '2017-01-01',NULL, 2018,'Regla FECHA_PROCESO 2018');

# %% [markdown]
# ## 2019

# %%
# %sql
DELETE FROM tfm_config.column_cast_rules WHERE source_year = 2019;
INSERT INTO tfm_config.column_cast_rules VALUES
('vehiculos', 'FECHA_PROCESO','date', 'd/M/yyyy'  ,NULL, TRUE, '2017-01-01',NULL, 2019,'Regla FECHA_PROCESO 2019'),
('vehiculos', 'FECHA_COMPRA' ,'date', 'd/M/yyyy'  ,NULL, TRUE, '2017-01-01',NULL, 2019,'Regla FECHA_PROCESO 2019')

# %% [markdown]
# ## 2020

# %%
# %sql
DELETE FROM tfm_config.column_cast_rules WHERE source_year = 2020;
INSERT INTO tfm_config.column_cast_rules VALUES
('vehiculos', 'FECHA_PROCESO','date', 'd-MMM-yy'  ,NULL, TRUE, '2017-01-01',NULL, 2020,'Regla FECHA_PROCESO 2020'),
('vehiculos', 'FECHA_COMPRA' ,'date', 'd-MMM-yy'  ,NULL, TRUE, '2017-01-01',NULL, 2020,'Regla FECHA_PROCESO 2020');

# %% [markdown]
# ## 2021

# %%
# %sql
DELETE FROM tfm_config.column_cast_rules WHERE source_year = 2021;
INSERT INTO tfm_config.column_cast_rules VALUES
('vehiculos', 'FECHA_PROCESO','date', 'd-MMM-yy'  ,NULL, TRUE, '2017-01-01',NULL, 2021,'Regla FECHA_PROCESO 2021'),
('vehiculos', 'FECHA_COMPRA' ,'date', 'd-MMM-yy'  ,NULL, TRUE, '2017-01-01',NULL, 2021,'Regla FECHA_PROCESO 2021');

# %% [markdown]
# ## 2022

# %%
# %sql
DELETE FROM tfm_config.column_cast_rules WHERE source_year = 2022;
INSERT INTO tfm_config.column_cast_rules VALUES
('vehiculos', 'FECHA_PROCESO','date', 'd-MMM-yy'  ,NULL, TRUE, '2017-01-01',NULL, 2022,'Regla FECHA_PROCESO 2022'),
('vehiculos', 'FECHA_COMPRA' ,'date', 'd-MMM-yy'  ,NULL, TRUE, '2017-01-01',NULL, 2022,'Regla FECHA_PROCESO 2022');

# %% [markdown]
# ## 2023

# %%
# %sql
DELETE FROM tfm_config.column_cast_rules WHERE source_year = 2023;
INSERT INTO tfm_config.column_cast_rules VALUES
('vehiculos', 'FECHA_PROCESO','date', 'd-MMM-yy'  ,NULL, TRUE, '2017-01-01',NULL, 2023,'Regla FECHA_PROCESO 2023'),
('vehiculos', 'FECHA_COMPRA' ,'date', 'd-MMM-yy'  ,NULL, TRUE, '2017-01-01',NULL, 2023,'Regla FECHA_PROCESO 2023');

# %% [markdown]
# ## 2024

# %%
# %sql
DELETE FROM tfm_config.column_cast_rules WHERE source_year = 2024;
INSERT INTO tfm_config.column_cast_rules VALUES
('vehiculos', 'FECHA_PROCESO','date', 'd/M/yyyy'  ,NULL, TRUE, '2017-01-01',NULL, 2024,'Regla FECHA_PROCESO 2024'),
('vehiculos', 'FECHA_COMPRA' ,'date', 'd/M/yyyy'  ,NULL, TRUE, '2017-01-01',NULL, 2024,'Regla FECHA_PROCESO 2024')

# %% [markdown]
# ## 2025

# %%
# %sql
DELETE FROM tfm_config.column_cast_rules WHERE source_year = 2025;
INSERT INTO tfm_config.column_cast_rules VALUES
('vehiculos', 'FECHA_PROCESO','date', 'd/M/yyyy'  ,NULL, TRUE, '2017-01-01',NULL, 2025,'Regla FECHA_PROCESO 2025'),
('vehiculos', 'FECHA_COMPRA' ,'date', 'd/M/yyyy'  ,NULL, TRUE, '2017-01-01',NULL, 2025,'Regla FECHA_PROCESO 2025');

# %% [markdown]
# ## General

# %%
# %sql
DELETE FROM tfm_config.column_cast_rules WHERE source_year = NULL;
INSERT INTO tfm_config.column_cast_rules VALUES
('vehiculos', 'ANIO_MODELO','int', NULL   ,NULL, TRUE, '2017-01-01',NULL, NULL,'Regla ANIO_MODELO General'),
('vehiculos', 'CILINDRAJE' ,'int', NULL   ,NULL, TRUE, '2017-01-01',NULL, NULL,'Regla CILINDRAJE General'),
('vehiculos', 'AVALUO'  ,'double', NULL   ,NULL, TRUE, '2017-01-01',NULL, NULL,'Regla CILINDRAJE General');

# %%
# %skip
# %sql
SELECT * FROM tfm_config.column_cast_rules
