# %%
# %sql
DROP SCHEMA IF EXISTS tfm_bronze CASCADE

# %%
# %sql
DROP SCHEMA IF EXISTS tfm_config CASCADE

# %%
# %sql
DROP SCHEMA IF EXISTS tfm_gold CASCADE

# %%
# %sql
DROP SCHEMA IF EXISTS tfm_silver CASCADE

# %%
# %sql
DROP SCHEMA IF EXISTS tfm_silver_ctg CASCADE

# %%
# %sql
DROP SCHEMA IF EXISTS tfm_silver_dim CASCADE

# %%
# %sql
DROP SCHEMA IF EXISTS tfm_silver_hmg CASCADE
