# %% [markdown]
# # Mapeo de cabeceras

# %% [markdown]
# ## 2017

# %%
# %sql
DELETE FROM tfm_config.header_mappings WHERE source_year = 2017;
INSERT INTO tfm_config.header_mappings VALUES
('vehiculos','SUB CATEGORIA 1'        ,'CATEGORIA'          ,TIMESTAMP '2017-01-01',NULL,2017, 10,'Regla 2017'),
('vehiculos','CODIGO VEHICULO 1'      ,'CODIGO_VEHICULO'    ,TIMESTAMP '2017-01-01',NULL,2017, 10,'Regla 2017'),
('vehiculos','FORMA DE ADQUISICION'   ,'TIPO_TRANSACCION'   ,TIMESTAMP '2017-01-01',NULL,2017, 10,'Regla 2017'),
('vehiculos','MARCA'                  ,'MARCA'              ,TIMESTAMP '2017-01-01',NULL,2017, 10,'Regla 2017'),
('vehiculos','MODELO'                 ,'MODELO'             ,TIMESTAMP '2017-01-01',NULL,2017, 10,'Regla 2017'),
('vehiculos','PAIS'                   ,'PAIS'               ,TIMESTAMP '2017-01-01',NULL,2017, 10,'Regla 2017'),
('vehiculos','ANO MODELO'             ,'ANIO_MODELO'        ,TIMESTAMP '2017-01-01',NULL,2017, 10,'Regla 2017'),
('vehiculos','CLASE'                  ,'CLASE'              ,TIMESTAMP '2017-01-01',NULL,2017, 10,'Regla 2017'),
('vehiculos','SUB CLASE'              ,'SUBCLASE'           ,TIMESTAMP '2017-01-01',NULL,2017, 10,'Regla 2017'),
('vehiculos','TIPO'                   ,'TIPO_VEHICULO'      ,TIMESTAMP '2017-01-01',NULL,2017, 10,'Regla 2017'),
('vehiculos','VALOR AVALUO'            ,'AVALUO'            ,TIMESTAMP '2017-01-01',NULL,2017, 10,'Regla 2017'),
('vehiculos','MES  REGISTRO VENTA'     ,'FECHA_PROCESO'     ,TIMESTAMP '2017-01-01',NULL,2017, 10,'Regla 2017'),
('vehiculos','TIPO SERVICIO'          ,'TIPO_SERVICIO'      ,TIMESTAMP '2017-01-01',NULL,2017, 10,'Regla 2017'),
('vehiculos','MES ADQUISICION'        ,'FECHA_COMPRA'       ,TIMESTAMP '2017-01-01',NULL,2017, 10,'Regla 2017'),
('vehiculos','CODIGO CANTON'          ,'CANTON'             ,TIMESTAMP '2017-01-01',NULL,2017, 10,'Regla 2017'),
('vehiculos','CODIGO COLOR 1'         ,'COLOR1'             ,TIMESTAMP '2017-01-01',NULL,2017, 10,'Regla 2017'),
('vehiculos','CODIGO COLOR 2'         ,'COLOR2'             ,TIMESTAMP '2017-01-01',NULL,2017, 10,'Regla 2017');

# %% [markdown]
# ## 2018

# %%
# %sql
DELETE FROM tfm_config.header_mappings WHERE source_year = 2018;
INSERT INTO tfm_config.header_mappings VALUES
('vehiculos','CODIGO SUB CATEGORIA'     ,'CATEGORIA'         ,TIMESTAMP '2017-01-01',NULL,2018, 10,'Regla 2018'),
('vehiculos','CODIGO VEHICULO'          ,'CODIGO_VEHICULO'   ,TIMESTAMP '2017-01-01',NULL,2018, 10,'Regla 2018'),
('vehiculos','FECHA PROCESO (MM/DD/AA)' ,'FECHA_PROCESO'     ,TIMESTAMP '2017-01-01',NULL,2018, 10,'Regla 2018'),
('vehiculos','FECHA COMPRA (MM/DD/AA)'  ,'FECHA_COMPRA'      ,TIMESTAMP '2017-01-01',NULL,2018, 10,'Regla 2018');

# %% [markdown]
# ## 2019

# %%
# %sql
DELETE FROM tfm_config.header_mappings WHERE source_year = 2019;
INSERT INTO tfm_config.header_mappings VALUES
('vehiculos','FECHA PROCESO (MM/DD/AA)' ,'FECHA_PROCESO'     ,TIMESTAMP '2017-01-01',NULL,2019, 10,'Regla 2019'),
('vehiculos','FECHA COMPRA (MM/DD/AA)'  ,'FECHA_COMPRA'      ,TIMESTAMP '2017-01-01',NULL,2019, 10,'Regla 2019');

# %% [markdown]
# ## 2020

# %%
# %sql
DELETE FROM tfm_config.header_mappings WHERE source_year = 2020;
INSERT INTO tfm_config.header_mappings VALUES
('vehiculos','FECHA PROCESO (DD/MM/AA)' ,'FECHA_PROCESO'     ,TIMESTAMP '2017-01-01',NULL,2020, 10,'Regla 2020'),
('vehiculos','FECHA COMPRA (DD/MM/AA)'  ,'FECHA_COMPRA'      ,TIMESTAMP '2017-01-01',NULL,2020, 10,'Regla 2020');

# %% [markdown]
# ## 2021

# %%
# %sql
DELETE FROM tfm_config.header_mappings WHERE source_year = 2021;
INSERT INTO tfm_config.header_mappings VALUES
('vehiculos','PERSONA NATURAL - SOCIEDAD' ,'TIPO_COMPRADOR'  ,TIMESTAMP '2017-01-01',NULL,2021, 10,'Regla 2021'),
('vehiculos','FECHA PROCESO (DD/MM/AA)' ,'FECHA_PROCESO'     ,TIMESTAMP '2017-01-01',NULL,2021, 10,'Regla 2021'),
('vehiculos','FECHA COMPRA (DD/MM/AA)'  ,'FECHA_COMPRA'      ,TIMESTAMP '2017-01-01',NULL,2021, 10,'Regla 2021');

# %% [markdown]
# ## 2022

# %%
# %sql
DELETE FROM tfm_config.header_mappings WHERE source_year = 2022;
INSERT INTO tfm_config.header_mappings VALUES
('vehiculos','FECHA PROCESO (DD/MM/AA)' ,'FECHA_PROCESO'     ,TIMESTAMP '2017-01-01',NULL,2022, 10,'Regla 2022'),
('vehiculos','FECHA COMPRA (DD/MM/AA)'  ,'FECHA_COMPRA'      ,TIMESTAMP '2017-01-01',NULL,2022, 10,'Regla 2022');

# %% [markdown]
# ## 2023

# %%
# %sql
DELETE FROM tfm_config.header_mappings WHERE source_year = 2023;
INSERT INTO tfm_config.header_mappings VALUES
('vehiculos','FECHA PROCESO (DD/MM/AA)' ,'FECHA_PROCESO'     ,TIMESTAMP '2017-01-01',NULL,2023, 10,'Regla 2023'),
('vehiculos','FECHA COMPRA (DD/MM/AA)'  ,'FECHA_COMPRA'      ,TIMESTAMP '2017-01-01',NULL,2023, 10,'Regla 2023');

# %% [markdown]
# ## 2024

# %%
# %sql
DELETE FROM tfm_config.header_mappings WHERE source_year = 2024;
INSERT INTO tfm_config.header_mappings VALUES
('vehiculos','FECHA PROCESO (DD/MM/AA)' ,'FECHA_PROCESO'     ,TIMESTAMP '2017-01-01',NULL,2024, 10,'Regla 2024'),
('vehiculos','FECHA COMPRA (DD/MM/AA)'  ,'FECHA_COMPRA'      ,TIMESTAMP '2017-01-01',NULL,2024, 10,'Regla 2024');

# %% [markdown]
# ## 2025

# %%
# %sql
DELETE FROM tfm_config.header_mappings WHERE source_year = 2025;
INSERT INTO tfm_config.header_mappings VALUES
('vehiculos','FECHA PROCESO (MM/DD/AA)' ,'FECHA_PROCESO'     ,TIMESTAMP '2017-01-01',NULL,2025, 10,'Regla 2025'),
('vehiculos','FECHA COMPRA (MM/DD/AA)'  ,'FECHA_COMPRA'      ,TIMESTAMP '2017-01-01',NULL,2025, 10,'Regla 2025');

# %% [markdown]
# ## General

# %%
# %sql
DELETE FROM tfm_config.header_mappings WHERE source_year = NULL;
INSERT INTO tfm_config.header_mappings VALUES
('vehiculos','CATEGORIA'              ,'CATEGORIA'          ,TIMESTAMP '2017-01-01',NULL,NULL, 10,'Regla General'),
('vehiculos','CODIGO DE VEHICULO'     ,'CODIGO_VEHICULO'    ,TIMESTAMP '2017-01-01',NULL,NULL, 10,'Regla General'),
('vehiculos','TIPO TRANSACCION'       ,'TIPO_TRANSACCION'   ,TIMESTAMP '2017-01-01',NULL,NULL, 10,'Regla General'),
('vehiculos','MARCA'                  ,'MARCA'              ,TIMESTAMP '2017-01-01',NULL,NULL, 10,'Regla General'),
('vehiculos','MODELO'                 ,'MODELO'             ,TIMESTAMP '2017-01-01',NULL,NULL, 10,'Regla General'),
('vehiculos','PAIS'                   ,'PAIS'               ,TIMESTAMP '2017-01-01',NULL,NULL, 10,'Regla General'),
('vehiculos','AÑO MODELO'             ,'ANIO_MODELO'        ,TIMESTAMP '2017-01-01',NULL,NULL, 10,'Regla General'),
('vehiculos','ANO MODELO'             ,'ANIO_MODELO'        ,TIMESTAMP '2017-01-01',NULL,NULL, 10,'Regla General'),
('vehiculos','CLASE'                  ,'CLASE'              ,TIMESTAMP '2017-01-01',NULL,NULL, 10,'Regla General'),
('vehiculos','SUB CLASE'              ,'SUBCLASE'           ,TIMESTAMP '2017-01-01',NULL,NULL, 10,'Regla General'),
('vehiculos','TIPO'                   ,'TIPO_VEHICULO'      ,TIMESTAMP '2017-01-01',NULL,NULL, 10,'Regla General'),
('vehiculos','AVALUO'                 ,'AVALUO'             ,TIMESTAMP '2017-01-01',NULL,NULL, 10,'Regla General'),
('vehiculos','FECHA PROCESO'          ,'FECHA_PROCESO'      ,TIMESTAMP '2017-01-01',NULL,NULL, 10,'Regla General'),
('vehiculos','TIPO SERVICIO'          ,'TIPO_SERVICIO'      ,TIMESTAMP '2017-01-01',NULL,NULL, 10,'Regla General'),
('vehiculos','CILINDRAJE'             ,'CILINDRAJE'         ,TIMESTAMP '2017-01-01',NULL,NULL, 10,'Regla General'),
('vehiculos','TIPO COMBUSTIBLE'       ,'TIPO_COMBUSTIBLE'   ,TIMESTAMP '2017-01-01',NULL,NULL, 10,'Regla General'),
('vehiculos','FECHA COMPRA'           ,'FECHA_COMPRA'       ,TIMESTAMP '2017-01-01',NULL,NULL, 10,'Regla General'),
('vehiculos','CANTON'                 ,'CANTON'             ,TIMESTAMP '2017-01-01',NULL,NULL, 10,'Regla General'),
('vehiculos','COLOR 1'                ,'COLOR1'             ,TIMESTAMP '2017-01-01',NULL,NULL, 10,'Regla General'),
('vehiculos','COLOR 2'                ,'COLOR2'             ,TIMESTAMP '2017-01-01',NULL,NULL, 10,'Regla General'),
('vehiculos','PERSONA NATURAL - JURIDICA' ,'TIPO_COMPRADOR' ,TIMESTAMP '2017-01-01',NULL,NULL, 10,'Regla General')
