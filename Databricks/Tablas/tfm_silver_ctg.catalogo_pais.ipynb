# %%
# %sql
CREATE DATABASE IF NOT EXISTS tfm_silver_ctg
COMMENT 'Homologaciones Capa Plata';

# %%
# %sql
--DROP TABLE IF EXISTS tfm_silver_ctg.cat_pais;
CREATE TABLE IF NOT EXISTS tfm_silver_ctg.cat_pais (
    pais_id                    BIGINT GENERATED ALWAYS AS IDENTITY, 
    pais                       STRING,    
    descripcion                STRING,    
    fecha_desde                TIMESTAMP,
    fecha_hasta                TIMESTAMP
)
USING DELTA
COMMENT 'Catálogo de paises';
