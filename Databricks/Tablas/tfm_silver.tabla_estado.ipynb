# %%
# %sql
CREATE DATABASE IF NOT EXISTS tfm_silver
COMMENT 'Capa Plata';

# %%
# %sql
--DROP TABLE IF EXISTS tfm_silver.state_files_processed ;
CREATE TABLE IF NOT EXISTS tfm_silver.state_files_processed (
  year INT,
  last_metadata_update timestamp,
  last_status STRING,
  last_checked_ts timestamp,
  last_file_path STRING,
  last_sha256 STRING,
  process_ts  TIMESTAMP,
  error_message STRING
)
USING DELTA;
