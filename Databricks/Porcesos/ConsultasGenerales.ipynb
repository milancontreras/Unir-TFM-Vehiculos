# %% [markdown]
# # Consultas Generales

# %%
# %sql
SELECT * FROM workspace.tfm_bronze.state_files ORDER BY year

# %%
# %sql
SELECT * FROM workspace.tfm_silver.state_files_processed ORDER BY year

# %% [markdown]
# # Procesado capa bronce

# %%
# %sql
SELECT * FROM workspace.tfm_silver.vehiculos

# %%
# %sql
SELECT 
  source_year AS ANIO
  ,count(*) 
FROM workspace.tfm_silver.vehiculos
GROUP by source_year
ORDER BY source_year

# %% [markdown]
# # Procesado Capa Oro

# %%
# %sql
SELECT * FROM workspace.tfm_gold.vehiculos

# %%
# %sql
SELECT 
  ANIO_ORIGEN 
  ,count(*) 
FROM workspace.tfm_gold.vehiculos
GROUP by ANIO_ORIGEN
ORDER BY ANIO_ORIGEN

# %%
# %sql
SELECT * FROM workspace.tfm_gold.dim_canton

# %%
# %sql
SELECT * FROM workspace.tfm_gold.dim_fecha
