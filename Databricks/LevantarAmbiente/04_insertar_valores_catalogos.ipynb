# %%
# %run "../Scripts/tfm_silver_ctg.poblar_catalogo_clase"

# %%
# %run "../Scripts/tfm_silver_ctg.poblar_catalogo_marca"

# %%
# %run "../Scripts/tfm_silver_ctg.poblar_catalogo_pais"

# %%
# %run "../Scripts/tfm_silver_ctg.poblar_catalogo_subclase"

# %%
# %run "../Scripts/tfm_silver_ctg.poblar_catalogo_tipo_combustible"

# %%
# %run "../Scripts/tfm_silver_ctg.poblar_catalogo_tipo_comprador"

# %%
# %run "../Scripts/tfm_silver_ctg.poblar_catalogo_tipo_servicio"

# %%
# %run "../Scripts/tfm_silver_ctg.poblar_catalogo_tipo_transaccion"

# %%
# %run "../Scripts/tfm_silver_ctg.poblar_catalogo_tipo_vehiculo"
