# %%
# %run "../Scripts/tfm_silver_hmg.homologacion_clase"

# %%
# %run "../Scripts/tfm_silver_hmg.homologacion_marca"

# %%
# %run "../Scripts/tfm_silver_hmg.homologacion_pais"

# %%
# %run "../Scripts/tfm_silver_hmg.homologacion_subclase"

# %%
# %run "../Scripts/tfm_silver_hmg.homologacion_tipo_combustible"

# %%
# %run "../Scripts/tfm_silver_hmg.homologacion_tipo_comprador"

# %%
# %run "../Scripts/tfm_silver_hmg.homologacion_tipo_servicio"

# %%
# %run "../Scripts/tfm_silver_hmg.homologacion_tipo_transaccion"

# %%
# %run "../Scripts/tfm_silver_hmg.homologacion_tipo_vehiculo"
